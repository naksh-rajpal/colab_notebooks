# %% [markdown]
# <a href="https://colab.research.google.com/github/naksh-rajpal/colab_notebooks/blob/main/python/python_course_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hello="Hello Naksh and Hezal"

# %%
print(hello)
# Out:
# Hello Naksh and Hezal

# %%
a=14

# %%
d=7

# %%
a+d
# Out:
# 21

# %%
a*d
# Out:
# 98

# %%
a-d
# Out:
# 7

# %%
a/d
# Out:
# 2.0

# %%
a%d
# Out:
# 0

# %%
sum=a+d
diff=a-d
div=a/d
mul=a*d

# %%
print(mul)
# Out:
# 98
