# %% [markdown]
# <a href="https://colab.research.google.com/github/naksh-rajpal/colab_notebooks/blob/main/python/02_rps_functions_naksh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
def get_user_choice():
  user_choice  = input("select one rock , paper or scissor ")
  print( user_choice )
  return user_choice

# %%
def get_computer_choice():
  options = ["rock" , "paper" , "scissor"]
  computer_choice = random.choice(options)
  print(computer_choice)
  return computer_choice
