# %% [markdown]
# <a href="https://colab.research.google.com/github/naksh-rajpal/colab_notebooks/blob/main/python/rock_paper_scissor_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_choice= input("select one option rock, paper or scissor : ")
# Out:
# select one option rock, paper or scissor : paper

# %%
import random

options = ['rock', 'paper', 'scissor']
computer_choice = random.choice(options)
print(f"Computer chose: {computer_choice}")
# Out:
# Computer chose: paper

# %%
if user_choice == computer_choice:
    print("It's a tie!")
elif (user_choice == 'rock' and computer_choice == 'scissor') or \
     (user_choice == 'paper' and computer_choice == 'rock') or \
     (user_choice == 'scissor' and computer_choice == 'paper'):
    print("You win!")
else:
    print("You lose!")
# Out:
# It's a tie!
