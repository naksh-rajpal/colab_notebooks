# %% [markdown]
# <a href="https://colab.research.google.com/github/naksh-rajpal/colab_notebooks/blob/main/python/00_basics/00_input_and_print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user=input("please enter a number")
# Out:
# please enter a number8

# %%
print(user)
# Out:
# 8

# %%
name=input("enter your name")
# Out:
# enter your namenaksh

# %%
print(name+ " bla")
# Out:
# naksh bla
